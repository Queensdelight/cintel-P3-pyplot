# %% [markdown]
# # Web Mining and Applied NLP (44-620)
#
# ## Matplotlib and pyplot
#
# ### Student Name: Bukola Adeniyan
#
# Perform the tasks described in the Markdown cells below.  When you have completed the assignment make sure your code cells have all been run (and have output beneath them) and ensure you have committed and pushed ALL of your changes to your assignment repository.
#
# Every question that requires you to write code will have a code cell underneath it; you may either write your entire solution in that cell or write it in a python file (`.py`), then import and run the appropriate code to answer the question.
#
# Do not use other external modules except `matplotlib` and `pyplot` (e.g. `math`, etc) for this assignment unless you are explicitly instructed to, though you may use built in python functions (`min`, `max`, etc) as you wish.
#
# For all of these questions, your plots must have an appropriate title and labeled axes.  Use the Matplotlib documentation as necessary to guide you through these exercises.

# %%
from collections import Counter
from random import randint
import matplotlib.pyplot as plt

print('All prereqs installed.')
# !pip list
# Out:
# All prereqs installed.
# Package           Version
# ----------------- -----------
# asttokens         2.4.1
# colorama          0.4.6
# comm              0.2.2
# contourpy         1.3.0
# cycler            0.12.1
# debugpy           1.8.7
# decorator         5.1.1
# executing         2.1.0
# fonttools         4.54.1
# ipykernel         6.29.5
# ipython           8.29.0
# jedi              0.19.1
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# kiwisolver        1.4.7
# matplotlib        3.9.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# numpy             2.1.3
# packaging         24.1
# parso             0.8.4
# pillow            11.0.0
# pip               24.2
# platformdirs      4.3.6
# prompt_toolkit    3.0.48
# psutil            6.1.0
# pure_eval         0.2.3
# Pygments          2.18.0
# pyparsing         3.2.0
# python-dateutil   2.9.0.post0
# pywin32           308
# pyzmq             26.2.0
# six               1.16.0
# stack-data        0.6.3
# ...

# %% [markdown]
# Question 1. Given the text below, create a bar plot (or a horizontal bar plot) that shows the frequency distribution of characters in the string.
# A dictionary has been created for you containing the characters and the frequencies of the characters.
# Ensure your bar plot has the bars labeled correctly (with the character it represents the frequency of).

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Text input
TEXT = "At three o’clock precisely I was at Baker Street, but Holmes had not yet returned. The landlady informed me that he had left the house shortly after eight o’clock in the morning. I sat down beside the fire, however, with the intention of awaiting him, however long he might be. I was already deeply interested in his inquiry, for, though it was surrounded by none of the grim and strange features which were associated with the two crimes which I have already recorded, still, the nature of the case and the exalted station of his client gave it a character of its own. Indeed, apart from the nature of the investigation which my friend had on hand, there was something in his masterly grasp of a situation, and his keen, incisive reasoning, which made it a pleasure to me to study his system of work, and to follow the quick, subtle methods by which he disentangled the most inextricable mysteries. So accustomed was I to his invariable success that the very possibility of his failing had ceased to enter into my head.".lower()

# Generate frequency of each character
letter_freq = dict(Counter(TEXT))

# Sort the dictionary by character for consistent plotting
sorted_letter_freq = dict(sorted(letter_freq.items()))

# Plotting the character frequency distribution as a horizontal bar plot
plt.figure(figsize=(10, 8))
plt.barh(list(sorted_letter_freq.keys()), list(sorted_letter_freq.values()), color="skyblue")
plt.title("Frequency Distribution of Characters in Text")
plt.xlabel("Frequency")
plt.ylabel("Character")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# Question 2. Generate a sequence of at least 5 random numbers (integers are fine), and visualize the data using both `scatter` and `plot` on different axes.  You may use the index of the value as its x value in the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a sequence of 5 random integers between 1 and 100
random_numbers = np.random.randint(1, 100, size=5)
indices = range(len(random_numbers))

# Set up the figure with two subplots: one for scatter and one for line plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Scatter plot
ax1.scatter(indices, random_numbers, color='blue', label='Random Numbers')
ax1.set_title("Scatter Plot of Random Numbers")
ax1.set_xlabel("Index")
ax1.set_ylabel("Value")
ax1.legend()

# Line plot
ax2.plot(indices, random_numbers, color='green', marker='o', label='Random Numbers')
ax2.set_title("Line Plot of Random Numbers")
ax2.set_xlabel("Index")
ax2.set_ylabel("Value")
ax2.legend()

# Show plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate a sequence of 5 random integers between 1 and 100
np.random.seed(42)  # Setting a seed for reproducibility
random_numbers = np.random.randint(1, 100, 5)

# Plotting the bar chart
plt.figure(figsize=(8, 6))
plt.bar(range(len(random_numbers)), random_numbers, color='skyblue')
plt.xlabel("Index")
plt.ylabel("Random Number")
plt.title("Bar Chart of Random Numbers")
plt.xticks(range(len(random_numbers)), labels=range(1, len(random_numbers) + 1))
plt.show()

# %%
# Creating a new scatter plot with some additional styling for variety
plt.figure(figsize=(8, 6))
plt.scatter(range(len(random_numbers)), random_numbers, color='purple', s=100, edgecolor='black', alpha=0.75)
plt.xlabel("Index")
plt.ylabel("Random Number")
plt.title("Scatter Plot of Random Numbers with Styling")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# Question 3. Do the same question as above, but change the syle and color of both the scatter and the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a new sequence of 5 random integers between 1 and 100
np.random.seed(10)  # Set a seed for reproducibility
random_numbers = np.random.randint(1, 100, 5)
indices = range(len(random_numbers))

# Set up the figure with two subplots: one for styled scatter and one for styled line plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Styled scatter plot
ax1.scatter(indices, random_numbers, color='crimson', s=150, edgecolor='black', alpha=0.8, marker='D')
ax1.set_title("Styled Scatter Plot of Random Numbers")
ax1.set_xlabel("Index")
ax1.set_ylabel("Value")
ax1.grid(True, linestyle='--', alpha=0.6)

# Styled line plot
ax2.plot(indices, random_numbers, color='darkblue', marker='o', linestyle='-.', linewidth=2, markersize=8)
ax2.set_title("Styled Line Plot of Random Numbers")
ax2.set_xlabel("Index")
ax2.set_ylabel("Value")
ax2.grid(True, linestyle='--', alpha=0.6)

# Display both plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a new sequence of random integers
np.random.seed(15)  # Set a seed for reproducibility
random_numbers = np.random.randint(1, 100, 5)
indices = range(len(random_numbers))

# Set up the figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Scatter plot with square markers
ax1.scatter(indices, random_numbers, color='teal', s=120, edgecolor='navy', alpha=0.7, marker='s')
ax1.set_title("Cool Tone Scatter Plot of Random Numbers")
ax1.set_xlabel("Index")
ax1.set_ylabel("Value")
ax1.grid(True, linestyle='--', color='lightgrey', alpha=0.7)

# Line plot with dashed line style and cyan color
ax2.plot(indices, random_numbers, color='cyan', marker='s', linestyle='--', linewidth=2, markersize=8)
ax2.set_title("Cool Tone Line Plot of Random Numbers")
ax2.set_xlabel("Index")
ax2.set_ylabel("Value")
ax2.grid(True, linestyle='--', color='lightgrey', alpha=0.7)

# Display both plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a new sequence of random integers
np.random.seed(20)  # Set a seed for reproducibility
random_numbers = np.random.randint(1, 100, 5)
indices = range(len(random_numbers))

# Set up the figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Scatter plot with triangle markers
ax1.scatter(indices, random_numbers, color='darkorange', s=130, edgecolor='firebrick', alpha=0.85, marker='^')
ax1.set_title("Warm Tone Scatter Plot of Random Numbers")
ax1.set_xlabel("Index")
ax1.set_ylabel("Value")
ax1.grid(True, linestyle='-', color='lightcoral', alpha=0.5)

# Line plot with dotted line style and red color
ax2.plot(indices, random_numbers, color='firebrick', marker='^', linestyle=':', linewidth=2, markersize=9)
ax2.set_title("Warm Tone Line Plot of Random Numbers")
ax2.set_xlabel("Index")
ax2.set_ylabel("Value")
ax2.grid(True, linestyle='-', color='lightcoral', alpha=0.5)

# Display both plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Question 4. Given the data sets below, plot or scatter both on the same set of axes.  You are plotting the time it takes to execute a sorting algorithm on a list of a given size; your x axis should be the size, and the y axis is time.  Assume that `insertion_sort_times[i]` is how long it took to sort a list of length `sizes[i]`.  Add a legend to your plot showing which is insertion sort and which is merge sort.  Use the variable names to determine which data is which.

# %%
import matplotlib.pyplot as plt

# Data sets
sizes = [10, 20, 50, 100, 1000, 5000]
insertion_sort_times = [0.0010253, 0.0027027, 0.0101472, 0.0381137, 3.6303399, 91.2180796]
merge_sort_times = [0.0016189, 0.0036356, 0.0090655, 0.020108, 0.2687474, 1.6147051]

# Plotting both insertion sort and merge sort on the same axes
plt.figure(figsize=(10, 6))

# Scatter plot for insertion sort
plt.scatter(sizes, insertion_sort_times, color='blue', label='Insertion Sort', marker='o')
plt.plot(sizes, insertion_sort_times, color='blue', linestyle='--')

# Scatter plot for merge sort
plt.scatter(sizes, merge_sort_times, color='red', label='Merge Sort', marker='s')
plt.plot(sizes, merge_sort_times, color='red', linestyle='-.')

# Labels and title
plt.xlabel("List Size")
plt.ylabel("Time (seconds)")
plt.title("Execution Time for Insertion Sort vs. Merge Sort")
plt.legend()
plt.yscale("log")  # Log scale for y-axis to better visualize differences

# Show plot
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
